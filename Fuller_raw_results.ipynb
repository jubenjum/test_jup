# %% [markdown]
# Loading the data

# %%
import pandas as pd

fd = pd.read_table('data/SPECTRAL_STACK50_NFILT40_6ca96b_raw_results.csv')
fd.sort_values('score')
# Out:
#    call_2 call_1  by     score         n
# 7      A*     BO   0  0.587186     23490
# 4       A  Nscrm   0  0.605800    206682
# 46  XKATR   KATR   0  0.633771    135792
# 10     A*  Nscrm   0  0.702940     37962
# 8      A*     KA   0  0.722011     66150
# 5       A     PY   0  0.729705   6513570
# 1       A     BO   0  0.737673    127890
# 2       A     KA   0  0.745964    360150
# 32  Nscrm     BO   0  0.751119     33060
# 27   KATR     KA   0  0.751207    904050
# 16     BO  Nscrm   0  0.753177     42180
# 0       A     A*   0  0.764550    103194
# 36     PY      A   0  0.774055   4528482
# 21     KA   KATR   0  0.777464   6789600
# 6      A*      A   0  0.799879    579474
# 22     KA  Nscrm   0  0.803912     70300
# 41     PY  Nscrm   0  0.811829    296666
# 39     PY     KA   0  0.828871    516950
# 20     KA     BO   0  0.839908     43500
# 33  Nscrm     KA   0  0.849184     93100
# 13     BO     A*   0  0.850047     21060
# 30  Nscrm      A   0  0.855728    815556
# ...
